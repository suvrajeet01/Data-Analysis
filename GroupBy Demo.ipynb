# %%
import numpy as np
import pandas as pd

# %%
company=pd.read_csv('Fortune501.csv')

# %%
company.head()
# Out:
#    Rank               Title  Employees       Sector  \
# 0     1             Walmart    2300000    Retailing
# 1     2  Berkshire Hathaway     367700   Financials
# 2     3               Apple     116000   Technology
# 3     4         Exxon Mobil      72700       Energy
# 4     5            McKesson      68000  Wholesalers
#
#                                    Industry         Hqlocation  Revenues  \
# 0                     General Merchandisers    Bentonville, AR    485873
# 1  Insurance: Property and Casualty (Stock)          Omaha, NE    223604
# 2               Computers, Office Equipment      Cupertino, CA    215639
# 3                        Petroleum Refining         Irving, TX    205004
# 4                  Wholesalers: Health Care  San Francisco, CA    192487
#
#    Profits
# 0  13643.0
# 1  24074.0
# 2  45687.0
# 3   7840.0
# 4   2258.0

# %%
company.shape
# Out:
# (500, 8)

# %%
sectors=company.groupby('Sector')   #it groups the same company'

# %%
len(sectors)
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              12
# Apparel                           5
# Business Services                20
# Chemicals                        14
# Energy                           57
# Engineering & Construction       13
# Financials                       84
# Food & Drug Stores                7
# Food, Beverages & Tobacco        24
# Health Care                      38
# Hotels, Restaurants & Leisure    10
# Household Products               12
# Industrials                      19
# Materials                        19
# Media                            11
# Motor Vehicles & Parts            9
# Retailing                        47
# Technology                       43
# Telecommunications               10
# Transportation                   17
# Wholesalers                      29
# dtype: int64

# %%
max(sectors.size())
# Out:
# 84

# %%
sectors.size().sort_values()
# Out:
# Sector
# Apparel                           5
# Food & Drug Stores                7
# Motor Vehicles & Parts            9
# Hotels, Restaurants & Leisure    10
# Telecommunications               10
# Media                            11
# Household Products               12
# Aerospace & Defense              12
# Engineering & Construction       13
# Chemicals                        14
# Transportation                   17
# Industrials                      19
# Materials                        19
# Business Services                20
# Food, Beverages & Tobacco        24
# Wholesalers                      29
# Health Care                      38
# Technology                       43
# Retailing                        47
# Energy                           57
# Financials                       84
# dtype: int64

# %%
sectors.size().sort_values().tail(1)
# Out:
# Sector
# Financials    84
# dtype: int64

# %%
#sectors.groups 
company.iloc[49,:]
# Out:
# Rank                             50
# Title           United Technologies
# Employees                    201600
# Sector          Aerospace & Defense
# Industry      Aerospace and Defense
# Hqlocation           Farmington, CT
# Revenues                      57244
# Profits                        5055
# Name: 49, dtype: object

# %%
sectors.get_group('Energy')  #it displays the groups.
# Out:
#      Rank                            Title  Employees  Sector  \
# 3       4                      Exxon Mobil      72700  Energy
# 18     19                          Chevron      55200  Energy
# 33     34                      Phillips 66      14800  Energy
# 36     37                    Valero Energy       9996  Energy
# 50     51               Marathon Petroleum      44460  Energy
# 78     79           Energy Transfer Equity      30992  Energy
# 88     89                           Exelon      34396  Energy
# 102   103              World Fuel Services       5000  Energy
# 114   115                   ConocoPhillips      13300  Energy
# 116   117                           Tesoro       6308  Energy
# 120   121                      Duke Energy      28798  Energy
# 121   122     Enterprise Products Partners       6800  Energy
# 140   141               Plains GP Holdings       5100  Energy
# 144   145                         Southern      32015  Energy
# ...

# %%
sectors.sum()
# Out:
#                                 Rank  Employees  Revenues   Profits
# Sector
# Aerospace & Defense             2416     863840    338302   25119.7
# Apparel                         1456     254650     66254    6318.5
# Business Services               6584     845050    194685   23107.1
# Chemicals                       3986     364906    188667   15918.3
# Energy                         14217     869511   1176417     370.6
# Engineering & Construction      4305     329090    124682    5072.2
# Financials                     20815    3161998   2067607  228461.2
# Food & Drug Stores               594    1390095    389686    8522.0
# Food, Beverages & Tobacco       5698    1000309    472806   56308.4
# Health Care                     6952    2341423   1318389  105383.9
# Hotels, Restaurants & Leisure   2860    1838742    121189   14510.6
# Household Products              3556     483344    180846   19803.7
# Industrials                     4506    1224296    418359   32826.1
# ...

# %%
sectors.mean()
# Out:
#                                      Rank      Employees      Revenues  \
# Sector
# Aerospace & Defense            201.333333   71986.666667  28191.833333
# Apparel                        291.200000   50930.000000  13250.800000
# Business Services              329.200000   42252.500000   9734.250000
# Chemicals                      284.714286   26064.714286  13476.214286
# Energy                         249.421053   15254.578947  20638.894737
# Engineering & Construction     331.153846   25314.615385   9590.923077
# Financials                     247.797619   37642.833333  24614.369048
# Food & Drug Stores              84.857143  198585.000000  55669.428571
# Food, Beverages & Tobacco      237.416667   41679.541667  19700.250000
# Health Care                    182.947368   61616.394737  34694.447368
# Hotels, Restaurants & Leisure  286.000000  183874.200000  12118.900000
# Household Products             296.333333   40278.666667  15070.500000
# ...

# %%
sectors.mean()['Revenues']
# Out:
# Sector
# Aerospace & Defense              28191.833333
# Apparel                          13250.800000
# Business Services                 9734.250000
# Chemicals                        13476.214286
# Energy                           20638.894737
# Engineering & Construction        9590.923077
# Financials                       24614.369048
# Food & Drug Stores               55669.428571
# Food, Beverages & Tobacco        19700.250000
# Health Care                      34694.447368
# Hotels, Restaurants & Leisure    12118.900000
# Household Products               15070.500000
# Industrials                      22018.894737
# Materials                         8934.473684
# Media                            16433.363636
# Motor Vehicles & Parts           43607.333333
# Retailing                        29431.510638
# Technology                       29246.255814
# Telecommunications               45997.800000
# Transportation                   20866.647059
# ...

# %%
sectors.mean()['Revenues'].sort_values()
# Out:
# Sector
# Materials                         8934.473684
# Engineering & Construction        9590.923077
# Business Services                 9734.250000
# Hotels, Restaurants & Leisure    12118.900000
# Apparel                          13250.800000
# Chemicals                        13476.214286
# Household Products               15070.500000
# Media                            16433.363636
# Food, Beverages & Tobacco        19700.250000
# Energy                           20638.894737
# Transportation                   20866.647059
# Industrials                      22018.894737
# Financials                       24614.369048
# Wholesalers                      27566.068966
# Aerospace & Defense              28191.833333
# Technology                       29246.255814
# Retailing                        29431.510638
# Health Care                      34694.447368
# Motor Vehicles & Parts           43607.333333
# Telecommunications               45997.800000
# ...
